# %%
import pandas as pd

# %%
history = pd.read_pickle('data/history.pickle')
orders = pd.read_pickle('data/orders.pickle')
indicator = pd.read_pickle('data/indicator.pickle')

# %%
indicator.head()
# Out:
#              DateTime     Seconds  Ticket Open/Close  DOCR(16)  DOCT(16)  \
# 0 2015-01-02 08:00:00  1420185600      -1  ON_NewBar   1.21045   1.20795
# 1 2015-01-02 08:01:00  1420185660      -1  ON_NewBar   1.21044   1.20779
# 2 2015-01-02 08:02:00  1420185720      -1  ON_NewBar   1.21039   1.20771
# 3 2015-01-02 08:03:00  1420185780      -1  ON_NewBar   1.21036   1.20752
# 4 2015-01-02 08:04:00  1420185840      -1  ON_NewBar   1.21035   1.20691
#
#    DOCS(16)   SMA(25)   SMA(50)  SMA(100)    ...       EMA(50)  EMA(100)  \
# 0   1.20545  1.210132  1.210213  1.210198    ...      1.210119  1.210443
# 1   1.20514  1.209916  1.210109  1.210146    ...      1.209914  1.210333
# 2   1.20503  1.209698  1.210005  1.210095    ...      1.209717  1.210225
# 3   1.20468  1.209455  1.209895  1.210037    ...      1.209510  1.210111
# 4   1.20346  1.209149  1.209755  1.209964    ...      1.209253  1.209968
#
#    MACD_MAIN  MACD_SIGNAL   STD(50)   ATR(25)    MOM(25)    RSI(7)   RSI(14)  \
# 0   0.000425     0.000080  0.000697  0.000290  99.598450  2.454705  5.972122
# 1   0.000757     0.000165  0.001021  0.000298  99.576957  2.321018  5.672258
# 2   0.001009     0.000275  0.001254  0.000302  99.560458  2.256739  5.538019
# 3   0.001229     0.000410  0.001476  0.000308  99.523337  2.100151  5.230394
# 4   0.001498     0.000580  0.001761  0.000353  99.440755  1.671632  4.401360
#
#      RSI(30)
# 0  13.667038
# 1  13.101757
# 2  12.855189
# 3  12.302474
# 4  10.794757
#
# [5 rows x 21 columns]
